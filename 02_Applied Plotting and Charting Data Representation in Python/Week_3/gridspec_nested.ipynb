# %%
# %matplotlib notebook

# %% [markdown]
# # Nested Gridspecs
#
#
# GridSpecs can be nested, so that a subplot from a parent GridSpec can
# set the position for a nested grid of subplots.

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec


def format_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5,1.0, "ax%d" % (i+1), va="bottom", ha="center")
        ax.tick_params(labelbottom=False, labelleft=False)


# gridspec inside gridspec
f = plt.figure()

gs0 = gridspec.GridSpec(1, 2, figure=f)

gs00 = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=gs0[0])
#gs00 = gs0[0].subgridspec(3, 3)

ax1 = f.add_subplot(gs00[:-1, :])
ax2 = f.add_subplot(gs00[-1, :-1])
ax3 = f.add_subplot(gs00[-1, -1])

# the following syntax does the same as the GridSpecFromSubplotSpec call above:
gs01 = gs0[1].subgridspec(3, 3)

ax4 = f.add_subplot(gs01[:, :-1])
ax5 = f.add_subplot(gs01[:-1, -1])
ax6 = f.add_subplot(gs01[-1, -1])

plt.suptitle("GridSpec Inside GridSpec")
format_axes(f)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.tan(3)
# Out:
# -0.1425465430742778

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-np.pi, np.pi, 50)
y = np.array([-np.pi,np.pi/2,np.pi])
# np.tan(np.array())
z = np.linspace(0, np.pi, 50)
# tan(x)    np.sin(x)/np.cos(x)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.plot(x, np.tan(x))
plt.plot(x, np.arctan(x))
plt.xlabel('Angle [rad]')
plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

def format_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5,1, "ax%d" % (i+1), va="bottom", ha="center")
        ax.tick_params(labelbottom=False, labelleft=False)


# gridspec inside gridspec
f = plt.figure()

gs0 = gridspec.GridSpec(1, 2, figure=f)

gs00 = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=gs0[0])
#gs00 = gs0[0].subgridspec(3, 3)

ax1 = f.add_subplot(gs00[0, 0])
ax2 = f.add_subplot(gs00[1, 0])
ax2.plot(x, np.sin(x))
ax3 = f.add_subplot(gs00[2, 0])
ax4 = f.add_subplot(gs00[:, 1:])

# the following syntax does the same as the GridSpecFromSubplotSpec call above:
gs01 = gs0[1].subgridspec(3, 3)

ax5 = f.add_subplot(gs01[:, 0])
ax6 = f.add_subplot(gs01[0, 1:])
ax7 = f.add_subplot(gs01[1, 1:])
ax8 = f.add_subplot(gs01[2, 1:])

plt.suptitle("GridSpec Inside GridSpec")
format_axes(f)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
